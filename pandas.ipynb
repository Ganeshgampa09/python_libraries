# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganeshgampa09/python_libraries/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas main data structures are :-1)series 2)Dataframe
#
# 1)pd.read_csv('filename.csv') -- Reads a CSV file.
#
# 2)df.to_csv('output.csv') -- save dataframe to a csv file.
#
# #Attribute/method
# 1)head(n)
#
# 2)tail(n)
#
# 3)info() -- summary of dataframe.
#
# 4)shape -- returns (rows,columns)
#
# 5)dtype -- data types of each column
#
# 6)merge()
#
# 7)set_index() and reset_index()
#
# 8)dropna() and fillna()
#
# #selecting & filtering data
# 1)data['column name'] or data.colname -- selects one column.
#
# 2)data[['col1','col2']] -- selecting multiple columns.
#
# 3)data.iloc[0] -- row by position.

# %% [markdown]
# If we want to read the data from csv file (comma seperated value) we need to import pandas first.
#
# read_csv is a function within the pandas library that is used to read a CSV (Comma-Separated Values) file and convert it into a DataFrame, which is a two-dimensional, size-mutable.

# %%
import pandas as pd
data=pd.read_csv('matches')

# %% [markdown]
# The type function is used to get what type of variable it is. Here, the output of type(data) is DATAFRAME.Because we have readed all the values from csv to data variable i mean dataframe.
#
# dataframe is a structured data(like combination of rows and columns.)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# If we print the data variable simply we can see all the data in that particular dataframe.

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# HEAD()-we can retrieve top rows.The default value of head is 5.

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# If we mention the value like Head(2) only 2 rows will be appeared.

# %%
data.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %% [markdown]
# TAIL()- we can retrieve rows from the last (simply we can check what is the last index like how many rows it consist of we can get an idea over it)

# %%
data.tail(5)
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %% [markdown]
# data.shape -- we can get an output like this (638,18) 638 stands for rows and 18 stands for columns.
#
# data.shape[0] -- we can get an output like (638,) means only rows.
#
# data.shape[1] -- we can get an output like (18,) means only columns.

# %%
data.shape
# Out:
# (636, 18)

# %%
data.shape[0]
# Out:
# 636

# %% [markdown]
# data.info() -- we can see the schema of the data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %% [markdown]
# let's say winner is the one column in  our csv file we can retrieve that by syntax
# data['winner']

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %% [markdown]
# suppose if we want to retrieve 3 columns : we need to pass them as a list.
# if the columns are greater than 1 we need to pass them in a list as shown below.
#
# data[['winner','city','pincode']]

# %%
data[['winner','city']]
# Out:
#                           winner       city
# 0            Sunrisers Hyderabad  Hyderabad
# 1         Rising Pune Supergiant       Pune
# 2          Kolkata Knight Riders     Rajkot
# 3                Kings XI Punjab     Indore
# 4    Royal Challengers Bangalore  Bangalore
# ..                           ...        ...
# 631  Royal Challengers Bangalore     Raipur
# 632  Royal Challengers Bangalore  Bangalore
# 633          Sunrisers Hyderabad      Delhi
# 634          Sunrisers Hyderabad      Delhi
# 635          Sunrisers Hyderabad  Bangalore
#
# [636 rows x 2 columns]

# %%
data[['winner','city']].shape
# Out:
# (636, 2)

# %% [markdown]
# data.iloc is used for retrieving rows.
#
# data.iloc[1:100:2] like it is similar to python 1 is starting index 100 is end index 2 is step index.

# %%
data.iloc[1:5]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 1           0       Rising Pune Supergiant            0               7
# 2           0        Kolkata Knight Riders            0              10
# ...

# %%
data.iloc[1:20:3]
# Out:
#     id  season       city        date                        team1  \
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 16  17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 19  20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# 1        Rising Pune Supergiant       Rising Pune Supergiant         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 7               Kings XI Punjab  Royal Challengers Bangalore           bat
# 10        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %% [markdown]
# let's say i have taken an ipl dataset i just want to retrieve that the matches which have been played in Hyderabad.
#
# data['city'] == 'Hyderabad'
# the output of the above code is like true true true.....
#
# we need to store that in a variable
# This process is called masking so,
#
# mask=data['city'] == 'Hyderabad'
# data[mask]

# %%
data['city']=='hyderabad'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
mask = data['city'] == 'Hyderabad'
data[mask]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
mask=data['city']=='Hyderabad'
data[mask].shape
# Out:
# (49, 18)

# %% [markdown]
# If we have a use with that in future. we can create a function and call that based on our requirements.

# %%
def match_count(city_name):
  mask = data['city'] == city_name
  return data[mask]

# %% [markdown]
# calling above function by passing the argument called Hyderabad.

# %%
match_count('Hyderabad')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %% [markdown]
# Now we are taking only one column called winner this is a series operation.
# when we work on multiple columns it is called as a dataframe.

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %% [markdown]
# from that winner column the value_counts() functions will counts the all values.

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %% [markdown]
# pandas.DataFrame.plot
# In pandas we have an function called plot. which is used for visualization.
#
# the syntax for that is:-
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html
#
# from the above link we can clearly see that.

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().plot(kind='area')
# Out:
# <Axes: xlabel='winner'>

# %% [markdown]
# Here the output is *series* because we have selected only one column from the dataframe.

# %%
type(data['winner'].value_counts())
# Out:
# pandas.core.series.Series

# %%
mycolumns=data['winner'].value_counts()
mycolumns.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %% [markdown]
# QUESTION:Find out which team has played most of the matches in final. we have two teams we need to consider the count of both teams like count of team1 and team2.The operations like +,-,*,/ can be performed on series data.

# %%
data['team1'].value_counts() + data['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %% [markdown]
# Q)Find out top 5  teams which has played most of the times in the final?
#
#
# ans)we have to add the values first and then by using the sort_values() function the values will be sorted if it is sorted as ascending we have to use tail() if the values are sorted as descending we have to use head().
# By default the sort value is ascending.

# %%
(data['winner'].value_counts()+data['winner'].value_counts()).sort_values().tail()
# Out:
# winner
# Kings XI Punjab                140
# Royal Challengers Bangalore    146
# Kolkata Knight Riders          154
# Chennai Super Kings            158
# Mumbai Indians                 184
# Name: count, dtype: int64

# %%
(data['winner'].value_counts()+data['winner'].value_counts()).sort_values(ascending=False).head()
# Out:
# winner
# Mumbai Indians                 184
# Chennai Super Kings            158
# Kolkata Knight Riders          154
# Royal Challengers Bangalore    146
# Kings XI Punjab                140
# Name: count, dtype: int64

# %% [markdown]
# From the dataset if we wanna sort we can use sort function like this too.

# %%
data.sort_values('city',ascending=False)
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %% [markdown]
# Let's say we want to sort the city and date for the above dataframe.

# %%
data.sort_values(['city','date'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city','date'],ascending=[False,True])
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 315  316    2012  Visakhapatnam  2012-04-09              Deccan Chargers
# 528  529    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 530  531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
data.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season',ascending=False)
# Out:
#      season                 winner
# 58     2017         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 575    2015         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 380    2012  Kolkata Knight Riders
# 306    2011    Chennai Super Kings
# 233    2010    Chennai Super Kings
# 173    2009        Deccan Chargers
# 116    2008       Rajasthan Royals

# %% [markdown]
# Sort_values() is a function.
#
# Here we are passing the 'season' column so it will be sort all 2008 together and 2009 together vice versa.

# %%
data.sort_values('season')
# Out:
#     id  season        city        date                   team1  \
# 63  64    2008     Kolkata  2008-04-20         Deccan Chargers
# 60  61    2008  Chandigarh  2008-04-19     Chennai Super Kings
# 61  62    2008       Delhi  2008-04-19        Rajasthan Royals
# 59  60    2008   Bangalore  2008-04-18   Kolkata Knight Riders
# 62  63    2008      Mumbai  2008-04-20          Mumbai Indians
# ..  ..     ...         ...         ...                     ...
# 27  28    2017      Mumbai  2017-04-24  Rising Pune Supergiant
# 28  29    2017        Pune  2017-04-26  Rising Pune Supergiant
# 17  18    2017       Delhi  2017-04-17        Delhi Daredevils
# 16  17    2017   Bangalore  2017-04-16  Rising Pune Supergiant
# 0    1    2017   Hyderabad  2017-04-05     Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 63        Kolkata Knight Riders              Deccan Chargers           bat
# ...

# %% [markdown]
# we have uploaded another csv file and loaded all the data into the data frame called company.

# %%
import pandas as pd
company = pd.read_csv('Fortune.csv', encoding='latin1')
company.head()
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2     3               Apple            1,16,000            3.0  $2,15,639
# 3     4         Exxon Mobil              72,700            2.0  $2,05,004
# 4     5            McKesson              68,000            5.0  $1,92,487
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035
# 2          -7.7%  $45,687.0        -14.4%  $3,21,686    $7,53,718
# 3         -16.7%   $7,840.0        -51.5%  $3,30,314    $3,40,056
# 4           6.2%   $2,258.0         53.0%    $56,563      $31,439

# %% [markdown]
# By shape attribute we can get how many rows and columns from the dataframe or csv file.

# %%
company.shape
# Out:
# (500, 10)

# %% [markdown]
# Again we are working on the ipl dataset that's why we have again loaded the data frame.

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# Now we are working on the GROUPBY.
#
# Let's say we wanna group all the cities together we can use group by at that time.After grouping them we can't access them directly instead we need to store them in a dataframe or a variable.

# %%
batches=data.groupby('city')

# %% [markdown]
# As similar to python we can use len function to get the length of the dataframe. The output of len(batches) is 30 i.e., we grouped the batches based on the city. we can simply say that there are 30 cities in the dataframe.

# %%
len(batches)
# Out:
# 30

# %%
len(data)
# Out:
# 636

# %%
batches.size()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
batches.groups
# Out:
# {'Abu Dhabi': [457, 459, 460, 464, 470, 471, 475], 'Ahmedabad': [179, 186, 194, 197, 481, 486, 497, 500, 525, 532, 535, 539], 'Bangalore': [4, 11, 16, 29, 41, 44, 56, 57, 59, 69, 73, 83, 89, 103, 110, 180, 183, 191, 196, 213, 216, 225, 241, 267, 279, 282, 290, 301, 311, 316, 325, 328, 349, 355, 366, 378, 382, 391, 400, 406, 410, 428, 431, 451, 480, 487, 491, 494, 509, 516, 524, 533, 537, 545, 549, 556, 570, 579, 586, 605, 610, 616, 619, 625, 632, 635], 'Bloemfontein': [160, 164], 'Cape Town': [117, 118, 119, 120, 123, 125, 129], 'Centurion': [132, 135, 136, 146, 147, 148, 155, 156, 165, 169, 170, 171], 'Chandigarh': [31, 34, 45, 47, 60, 68, 72, 80, 93, 96, 107, 176, 192, 195, 204, 214, 242, 255, 283, 286, 320, 329, 332, 339, 353, 365, 390, 399, 408, 435, 439, 447, 504, 508, 511, 543, 551, 565, 568, 578, 585, 588, 596, 611, 614, 621], 'Chennai': [66, 70, 78, 84, 90, 106, 109, 178, 189, 201, 205, 210, 221, 223, 234, 247, 261, 271, 275, 288, 296, 305, 306, 307, 319, 331, 333, 342, 346, 
# ...

# %% [markdown]
# Here batches is already a sorted data from that i want get only Hyderabad. we can use get_group function and we need to pass the parameter.

# %%
batches.get_group('Hyderabad')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
batches.sum().head()
# Out:
#                  id  season  \
# city
# Abu Dhabi      3263   14098
# Ahmedabad      4863   24156
# Bangalore     22299  132861
# Bloemfontein    326    4018
# Cape Town       858   14063
#
#                                                            date  \
# city
# Abu Dhabi     2014-04-162014-04-182014-04-182014-04-212014-0...
# Ahmedabad     2010-03-152010-03-202010-03-262010-03-282014-0...
# Bangalore     2017-04-082017-04-142017-04-162017-04-272017-0...
# Bloemfontein                               2009-05-152009-05-17
# Cape Town     2009-04-182009-04-182009-04-192009-04-192009-0...
#
#                                                           team1  \
# city
# Abu Dhabi     Kolkata Knight RidersChennai Super KingsSunris...
# Ahmedabad     Rajasthan RoyalsRajasthan RoyalsDeccan Charger...
# Bangalore     Royal Challengers BangaloreRoyal Challengers B...
# Bloemfontein                   Delhi DaredevilsDelhi Daredevils
# ...

# %% [markdown]
# we have imported another csv file called deliveries.csv

# %%
import pandas as pd
delivery = pd.read_csv('deliveries.csv')

# %%
delivery.shape
# Out:
# (150460, 21)

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# like deliveries.csv is a csv file that is related to runs of every batsman for the whole ipl.
#
# suppose i want to get top 5 batsmans who scored more runs.
#
# ans)we need to group all the batsmans together first for all the seasons.
# Then we have to sum the score of the batsman and we want only top 5 so we need sort them in descending order.

# %%
delivery.groupby('batsman').sum().sort_values(by='batsman_runs',ascending=False)
# Out:
#               match_id  inning  \
# batsman
# SK Raina       1079285    4748
# V Kohli        1304291    5112
# RG Sharma      1081920    4822
# G Gambhir      1072760    5510
# DA Warner      1085379    4258
# ...                ...     ...
# RR Bhatkal         640       2
# M Ashwin           592       2
# Abdur Razzak       202       4
# IC Pandey          822       4
# Sunny Gupta        380       2
#
#                                                    batting_team  \
# batsman
# SK Raina      Gujarat LionsGujarat LionsGujarat LionsGujarat...
# V Kohli       Royal Challengers BangaloreRoyal Challengers B...
# RG Sharma     Mumbai IndiansMumbai IndiansMumbai IndiansMumb...
# G Gambhir     Kolkata Knight RidersKolkata Knight RidersKolk...
# DA Warner     Sunrisers HyderabadSunrisers HyderabadSunriser...
# ...                                                         ...
# RR Bhatkal    Royal Challengers BangaloreRoyal Challengers B...
# ...

# %% [markdown]
# In sql,we need to join multiple tables for solving difficult queries it is called as joins.
#
# similarly in pandas when we join two or more tables it is called as merge().

# %%
new_data=delivery.merge(data,left_on='match_id',right_on='id')

# %%
new_data.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='season',keep='first').sort_values('season')[['season','batsman']]
# Out:
#     season       batsman
# 10    2008      SE Marsh
# 14    2009     ML Hayden
# 9     2010  SR Tendulkar
# 11    2011      CH Gayle
# 2     2012      CH Gayle
# 3     2013    MEK Hussey
# 6     2014    RV Uthappa
# 17    2015     DA Warner
# 0     2016       V Kohli
# 7     2017     DA Warner

# %%
data.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %% [markdown]
# Rename() function is used to rename the column names in the data frame.
# But the changes made by that is temparory.If we want to change them permenantly we have to pass inplace=true(So dangerous because it effects the original data).

# %%
data.rename(columns={'city':'place','date':'dom'})
# Out:
#       id  season      place         dom                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# #set_index() and reset_index()

# %% [markdown]
# In the below output id is already a primary key means we can easily identify rows.But pandas generates another index for us that starts with 0.we can also remove that by using set_index().

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.set_index('id',inplace=True)

# %% [markdown]
# Now we removed the index which is generated by pandas using set_index().I have used inplace='True' that changes the original data.

# %%
data
# Out:
#      season       city        date                        team1  \
# id
# 1      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      2017       Pune  2017-04-06               Mumbai Indians
# 3      2017     Rajkot  2017-04-07                Gujarat Lions
# 4      2017     Indore  2017-04-08       Rising Pune Supergiant
# 5      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...        ...         ...                          ...
# 632    2016     Raipur  2016-05-22             Delhi Daredevils
# 633    2016  Bangalore  2016-05-24                Gujarat Lions
# 634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 635    2016      Delhi  2016-05-27                Gujarat Lions
# 636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# id
# 1    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# When we use reset_index() the index will be added.

# %%
data['winner'].reset_index()
# Out:
#       id                       winner
# 0      1          Sunrisers Hyderabad
# 1      2       Rising Pune Supergiant
# 2      3        Kolkata Knight Riders
# 3      4              Kings XI Punjab
# 4      5  Royal Challengers Bangalore
# ..   ...                          ...
# 631  632  Royal Challengers Bangalore
# 632  633  Royal Challengers Bangalore
# 633  634          Sunrisers Hyderabad
# 634  635          Sunrisers Hyderabad
# 635  636          Sunrisers Hyderabad
#
# [636 rows x 2 columns]

# %% [markdown]
# #Dropna() and Fillna()

# %% [markdown]
# Dropna() is used to identify missing values in our dataframe.
#
# From the below outputs we can say that in our dataframe every row has a value.The how='all' means it will detect if all values of a row is N/A then it will consider but in our case every row has a value.

# %%
data.shape
# Out:
# (636, 17)

# %%
data.dropna(how='all').shape
# Out:
# (636, 17)

# %%
data.dropna(subset=['umpire3','umpire2']).shape
# Out:
# (0, 17)

# %% [markdown]
# #Fillna()
#
# we can use fillna() function to replace the missing values in our data frame.Before umpire_3 has no value but now it is 0.

# %%
data.fillna(0)
# Out:
#      season       city        date                        team1  \
# id
# 1      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      2017       Pune  2017-04-06               Mumbai Indians
# 3      2017     Rajkot  2017-04-07                Gujarat Lions
# 4      2017     Indore  2017-04-08       Rising Pune Supergiant
# 5      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...        ...         ...                          ...
# 632    2016     Raipur  2016-05-22             Delhi Daredevils
# 633    2016  Bangalore  2016-05-24                Gujarat Lions
# 634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 635    2016      Delhi  2016-05-27                Gujarat Lions
# 636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# id
# 1    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# Above fillna() function will replace all the null values with 0.But if we want to replace the values for only one column we need to use the below syntax.

# %%
data['umpire3'].fillna('Not mentioned')
# Out:
# 0      Not mentioned
# 1      Not mentioned
# 2      Not mentioned
# 3      Not mentioned
# 4      Not mentioned
#            ...
# 631    Not mentioned
# 632    Not mentioned
# 633    Not mentioned
# 634    Not mentioned
# 635    Not mentioned
# Name: umpire3, Length: 636, dtype: object
